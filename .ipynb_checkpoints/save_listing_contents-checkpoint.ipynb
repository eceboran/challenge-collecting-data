# %% [markdown]
# ## Save listing contents as text
# Save the contents of each listing (house or apartment) into a text file, to be used later by BeautifulSoup.

# %%
# Import necessary libraries
from selenium import webdriver
from bs4 import BeautifulSoup
import os
import time
import random
import re
from queue import Queue
from threading import Thread
import requests

# %%
# Create a folder for data
data_folder_path = os.path.abspath("./data/")
if not os.path.exists(data_folder_path):
    os.makedirs(data_folder_path)

# %%
# Folder for page contents
contents_folder_path = os.path.join(data_folder_path,"contents/")
if not os.path.exists(contents_folder_path):
    os.makedirs(contents_folder_path)

# %%
# The txt file for the links of the individual listings
listings_url_file_name = "listings_url_list_processed.txt" 
listings_url_file_path = os.path.join(data_folder_path,listings_url_file_name)

# %%
# Load links of listings
with open(listings_url_file_path, "r+") as file:
    urls = file.readlines()
print(urls)
# Out:
# ['https://www.immoweb.be/en/classified/apartment/for-sale/ixelles/1050/8956021\n', 'https://www.immoweb.be/en/classified/house/for-sale/denderleeuw/9470/9528614\n', 'https://www.immoweb.be/en/classified/duplex/for-sale/geraardsbergen/9500/9555271\n', 'https://www.immoweb.be/en/classified/house/for-sale/uccle/1180/9064209\n', 'https://www.immoweb.be/en/classified/house/for-sale/anderlecht/1070/9391667\n', 'https://www.immoweb.be/en/classified/duplex/for-sale/arlon/6700/9551192\n', 'https://www.immoweb.be/en/classified/house/for-sale/bredene/8450/9559175\n', 'https://www.immoweb.be/en/classified/villa/for-sale/nivelles/1400/9451348\n', 'https://www.immoweb.be/en/classified/apartment/for-sale/uccle/1180/9317406\n', 'https://www.immoweb.be/en/classified/house/for-sale/woluwe-saint-pierre/1150/9406426\n', 'https://www.immoweb.be/en/classified/house/for-sale/limal-wavre/1300/9478369\n', 'https://www.immoweb.be/en/classified/house/for-sale/wangenies/6220/9419687\n', 'https://www.immoweb.be/en/classified/house/for-sale/erpe-mere/9420/9556993\n', 'https://www.immoweb.be/en/classified/house/for-sale/antwerpen/2600/9551501\n', 'https://www.immoweb.be/en/classified/loft/for-sale/kortrijk/8500/9518565\n', 'https://www.immoweb.be/en/classified/house/for-sale/floreffe/5150/9375310\n', 'https://www.immoweb.be/en/classified/apartment/for-sale/nivelles/1400/9357628\n', 'https://www.immoweb.be/en/classified/apartment/for-sale/braine-lalleud/1420/9410511\n', 'https://www.immoweb.be/en/classified/house/for-sale/waregem/8790/9439526\n', 'https://www.immoweb.be/en/classified/penthouse/for-sale/forest/1190/9314087\n', 'https://www.immoweb.be/en/classified/apartment/for-sale/etterbeek/1040/9374417\n', 'https://www.immoweb.be/en/classified/duplex/for-sale/knokke-heist/8300/9559342\n', 'https://www.immoweb.be/en/classified/apartment/for-sale/auderghem/1160/9557465\n', 'https://www.immoweb.be/en/classified/house/for-sale/mouscron/7700/9469346\n', 'https://www.immoweb.be/en/classified/house/for-sale/antwerp/2000/9428428\n', 'https://www.immoweb.be/en/classified/house/for-sale/trooz/4870/9520291\n', 'https://www.immoweb.be/en/classified/duplex/for-sale/liege-1/4000/8549833\n', 'https://www.immoweb.be/en/classified/house/for-sale/profondeville/5170/9534380\n', 'https://www.immoweb.be/en/classified/house/for-sale/waregem/8793/9255481\n', 'https://www.immoweb.be/en/classified/house/for-sale/evere/1140/9382725\n', 'https://www.immoweb.be/en/classified/house/for-sale/halle/1500/9522733\n', 'https://www.immoweb.be/en/classified/house/for-sale/isnes/5032/9511387\n', 'https://www.immoweb.be/en/classified/house/for-sale/hermalle-sous-huy/4480/9442043\n', 'https://www.immoweb.be/en/classified/apartment-block/for-sale/ath/7800/9374996\n', 'https://www.immoweb.be/en/classified/house/for-sale/herve-chaineux/4650/9470463\n', 'https://www.immoweb.be/en/classified/apartment/for-sale/antwerp/2660/8553542\n', 'https://www.immoweb.be/en/classified/house/for-sale/wavre/1301/9381693\n', 'https://www.immoweb.be/en/classified/apartment/for-sale/hoboken/2660/9546365\n', 'https://www.immoweb.be/en/classified/apartment/for-sale/bruxelles/1000/9015936\n', 'https://www.immoweb.be/en/classified/apartment/for-sale/ixelles/1050/9412877\n', 'https://www.immoweb.be/en/classified/apartment/for-sale/herzele/9550/9027535\n', 'https://www.immoweb.be/en/classified/house/for-sale/ixelles/1050/9492117\n', 'https://www.immoweb.be/en/classified/house/for-sale/middelkerke/8430/9390693\n', 'https://www.immoweb.be/en/classified/house/for-sale/ninove/9400/9552731\n', 'https://www.immoweb.be/en/classified/villa/for-sale/riviere/5170/9275501\n', 'https://www.immoweb.be/en/classified/apartment-block/for-sale/bruxelles/1000/9452032\n', 'https://www.immoweb.be/en/classified/apartment/for-sale/bruxelles/1000/9500537\n', 'https://www.immoweb.be/en/classified/house/for-sale/moen/8552/9557394\n', 'https://www.immoweb.be/en/classified/apartment/for-sale/antwerp/2060/9166210\n', 'https://www.immoweb.be/en/classi ...

# %%
print(len(urls))
# Out:
# 9306

# %%
# For a single entry, get contents as a string
#set up the queue to hold all the urls
q = Queue(maxsize=0)
# Use many threads (50 max, or one for each url)
num_theads = min(20, len(urls))

# %%
# Populating Queue with tasks
# Specify the urls to run
range_url = range(0,min(30, len(urls)))  # Change to run for each person

# %%
#Populating Queue with tasks
results = [{} for x in urls];
# load up the queue with the urls to fetch and the index for each job (as a tuple):
for i in range_url:
    #need the index and the url in each queue item.
    q.put((i,urls[i],contents_folder_path))

# %%
print(q.queue)
# Out:
# deque([(0, 'https://www.immoweb.be/en/classified/apartment/for-sale/ixelles/1050/8956021\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (1, 'https://www.immoweb.be/en/classified/house/for-sale/denderleeuw/9470/9528614\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (2, 'https://www.immoweb.be/en/classified/duplex/for-sale/geraardsbergen/9500/9555271\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (3, 'https://www.immoweb.be/en/classified/house/for-sale/uccle/1180/9064209\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (4, 'https://www.immoweb.be/en/classified/house/for-sale/anderlecht/1070/9391667\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (5, 'https://www.immoweb.be/en/classified/duplex/for-sale/arlon/6700/9551192\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (6, 'https://www.immoweb.be/en/classified/house/for-sale/bredene/8450/9559175\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (7, 'https://www.immoweb.be/en/classified/villa/for-sale/nivelles/1400/9451348\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (8, 'https://www.immoweb.be/en/classified/apartment/for-sale/uccle/1180/9317406\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (9, 'https://www.immoweb.be/en/classified/house/for-sale/woluwe-saint-pierre/1150/9406426\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (10, 'https://www.immoweb.be/en/classified/house/for-sale/limal-wavre/1300/9478369\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (11, 'https://www.immoweb.be/en/classified/house/for-sale/wangenies/6220/9419687\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (12, 'https://www.immoweb.be/en/classified/house/for-sale/erpe-mere/9420/9556993\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (13, 'https://www.immoweb.be/en/classified/house/for-sale/antwerpen/2600/9551501\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (14, 'https://www.immoweb.be/en/classified/loft/for-sale/kortrijk/8500/9518565\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (15, 'https://www.immoweb.be/en/classified/house/for-sale/floreffe/5150/9375310\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (16, 'https://www.immoweb.be/en/classified/apartment/for-sale/nivelles/1400/9357628\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (17, 'https://www.immoweb.be/en/classified/apartment/for-sale/braine-lalleud/1420/9410511\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (18, 'https://www.immoweb.be/en/classified/house/for-sale/waregem/8790/9439526\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (19, 'https://www.immoweb.be/en/classified/penthouse/for-sale/forest/1190/9314087\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (20, 'https://www.immoweb.be/en/classified/apartment/for-sale/etterbeek/1040/9374417\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (21, 'https://www.immoweb.be/en/classified/duplex/for-sale/knokke-heist/8300/9559342\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (22, 'https://www.immoweb.be/en/classified/apartment/for-sale/auderghem/1160/9557465\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (23, 'https://www.immoweb.be/en/classified/house/for-sale/mouscron/7700/9469346\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/'), (24, 'https://www.immoweb.be/en/classified/house/for-sale/antwerp/2000/9428428\n', 'C:\\Users\\ecebo\\MyRepos\\challenge-collecting-data\\data\\contents/') ...

# %%
def save_contents_to_text(q, result):
    while not q.empty():
        work = q.get()  #fetch new work from the Queue
        #try:
        url = work[1]
        folder_path = work[2]
        print(folder_path)
        m = re.search("/(?P<immoweb_code>[\w\-]+)$", url)
        immoweb_code = m.group("immoweb_code")
            
        file_name = f"Contents_{immoweb_code}.txt"
        filepath = os.path.join(folder_path,file_name)
        print(filepath)
        # Check if the text file already exists
        if os.path.exists(filepath):
            print("File already exists")
            # return True
            
        print(url)
        r = requests.get(url)
        time.sleep(random.uniform(2.0, 3.0))
        print("Made request")
        # Display the requested url and the return of the server
        print(url, r.status_code)
        # Store the HTML content of the website in a text
        page_contents = r.text
        print(len(page_contents))
        
        with open(filepath,"w", encoding="utf-8") as input_file:
            input_file.write(page_contents)

        print("Written file ..." + immoweb_code)
            
             # Save file to text
        #except:
            #print('Error with URL check!')
        # Signal to the queue that task has been processed
        q.task_done()
    return True

# %%
# Starting worker threads on queue processing
for i in range(num_theads):
    print('Starting thread ', i)
    worker = Thread(target=save_contents_to_text, args=(q,results))
    worker.setDaemon(True)    #setting threads as "daemon" allows main program to 
                              #exit eventually even if these dont finish 
                              #correctly.
    worker.start()
# Out:
# Starting thread  0
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_8956021.txt
# Starting thread  1
# https://www.immoweb.be/en/classified/apartment/for-sale/ixelles/1050/8956021
#
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9528614.txt
# Starting thread  2
# https://www.immoweb.be/en/classified/house/for-sale/denderleeuw/9470/9528614
#
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9555271.txt
# https://www.immoweb.be/en/classified/duplex/for-sale/geraardsbergen/9500/9555271
#
# Starting thread  3
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9064209.txt
# Starting thread  4
# https://www.immoweb.be/en/classified/house/for-sale/uccle/1180/9064209
#
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9391667.txt
# https://www.immoweb.be/en/classified/house/for-sale/anderlecht/1070/9391667
#
# Starting thread  5
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9551192.txt
# https://www.immoweb.be/en/classified/duplex/for-sale/arlon/6700/9551192
#
# Starting thread  6
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9559175.txt
# Starting thread  7
# https://www.immoweb.be/en/classified/house/for-sale/bredene/8450/9559175
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9451348.txt
# https://www.immoweb.be/en/classified/villa/for-sale/nivelles/1400/9451348
#
#
# Starting thread  8
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9317406.txt
# Starting thread  9
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9406426.txt
# Starting thread  10
# https://www.immoweb.be/en/classified/house/for-sale/woluwe-saint-pierre/1150/9406426
#
# https://www.immoweb.be/en/classified/apartment/for-sale/uccle/1180/9317406
#
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9478369.txt
# https://www.immoweb.be/en/classified/house/for-sale/limal-wavre/1300/9478369
#
# Starting thread  11
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9419687.txt
# Starting thread  12
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9556993.txt
# Starting thread https://www.immoweb.be/en/classified/house/for-sale/wangenies/6220/9419687
#
# https://www.immoweb.be/en/classified/house/for-sale/erpe-mere/9420/9556993
#
#  13
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9551501.txt
# Starting thread  14
# https://www.immoweb.be/en/classified/house/for-sale/antwerpen/2600/9551501
#
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9518565.txt
# https://www.immoweb.be/en/classified/loft/for-sale/kortrijk/8500/9518565
#
# Starting thread  15
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9375310.txt
# Starting thread https://www.immoweb.be/en/classified/house/for-sale/floreffe/5150/9375310
#
#  16
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9357628.txt
# https://www.immoweb.be/en/classified/apartment/for-sale/nivelles/1400/9357628
#
# Starting thread  17
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Starting thread  18
#
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9439526.txt
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9410511.txt
# https://www.immoweb.be/en/classified/house/for-sale/waregem/8790/9439526
# https://www.immoweb.be/en/classified/apartment/for-sale/braine-lalleud/1420/9410511
#
#
# Starting thread  19
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9314087.txt
# https://www.immoweb.be/en/classified/penthouse/for-sale/forest/1190/9314087

# %%
# Wait until the queue has been processed
q.join()
print('All tasks completed.')
# Out:
# Made request
# https://www.immoweb.be/en/classified/duplex/for-sale/geraardsbergen/9500/9555271
#  200
# 166041
# Written file ...9555271
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9374417.txt
# https://www.immoweb.be/en/classified/apartment/for-sale/etterbeek/1040/9374417
#
# Made request
# https://www.immoweb.be/en/classified/house/for-sale/woluwe-saint-pierre/1150/9406426
#  200
# 185199
# Written file ...9406426
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9559342.txt
# https://www.immoweb.be/en/classified/duplex/for-sale/knokke-heist/8300/9559342
#
# Made request
# https://www.immoweb.be/en/classified/house/for-sale/anderlecht/1070/9391667
#  200
# 177729
# Written file ...9391667
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9557465.txt
# https://www.immoweb.be/en/classified/apartment/for-sale/auderghem/1160/9557465
#
# Made request
# https://www.immoweb.be/en/classified/apartment/for-sale/ixelles/1050/8956021
#  200
# 160249
# Written file ...8956021
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9469346.txt
# https://www.immoweb.be/en/classified/house/for-sale/mouscron/7700/9469346
#
# Made request
# https://www.immoweb.be/en/classified/apartment/for-sale/uccle/1180/9317406
#  200
# 174382
# Written file ...9317406
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9428428.txt
# https://www.immoweb.be/en/classified/house/for-sale/antwerp/2000/9428428
#
# Made request
# https://www.immoweb.be/en/classified/house/for-sale/erpe-mere/9420/9556993
#  200
# 169151
# Made request
# https://www.immoweb.be/en/classified/apartment/for-sale/nivelles/1400/9357628
#  200
# 175761
# Written file ...9556993
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9520291.txt
# Written file ...9357628
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_8549833.txt
# https://www.immoweb.be/en/classified/house/for-sale/trooz/4870/9520291
#
# https://www.immoweb.be/en/classified/duplex/for-sale/liege-1/4000/8549833
#
# Made request
# https://www.immoweb.be/en/classified/house/for-sale/bredene/8450/9559175
#  200
# 163765
# Written file ...9559175
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9534380.txt
# https://www.immoweb.be/en/classified/house/for-sale/profondeville/5170/9534380
#
# Made request
# https://www.immoweb.be/en/classified/house/for-sale/floreffe/5150/9375310
#  200
# 170385
# Made request
# https://www.immoweb.be/en/classified/penthouse/for-sale/forest/1190/9314087
#  200
# 171823
# Written file ...9375310Written file ...9314087
#
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9255481.txt
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/
# C:\Users\ecebo\MyRepos\challenge-collecting-data\data\contents/Contents_9382725.txt
# https://www.immoweb.be/en/classified/house/for-sale/evere/1140/9382725
#
# https://www.immoweb.be/en/classified/house/for-sale/waregem/8793/9255481
#
# Made request
# https://www.immoweb.be/en/classified/house/for-sale/waregem/8790/9439526
#  200
# 171679
# Written file ...9439526
# Made request
# https://www.immoweb.be/en/classified/duplex/for-sale/arlon/6700/9551192
#  200
# 160635
# Written file ...9551192
# Made request
# https://www.immoweb.be/en/classified/house/for-sale/wangenies/6220/9419687
#  200
# 166984
# Written file ...9419687
# Made request
# https://www.immoweb.be/en/classified/house/for-sale/denderleeuw/9470/9528614
#  200
# 172046
# Written file ...9528614
# Made request
# https://www.immoweb.be/en/classified/house/for-sale/uccle/1180/9064209
#  200
# 167160
# Written file ...9064209
# Made request
# https://www.immoweb.be/en/classified/house/for-sale/limal-wavre/1300/9478369
#  200
# 190184
# Written file ...9478369
# Made request
# https://www.immoweb.be/en/classified/apartment/for-sale/braine-lalleud/1420/9410511
#  200
# 154375
# Written file ...9410511
# Made request
# https://www.immoweb.be/en/classified/villa/for-sale/nivelles/1400/9451348
#  200
# 177112
# Written file ...9451348
# Made requestMade request
# https://www.immoweb.be/en/classified/house/for-sale/antwerpen/2600/9551501
#  200
# 176676
#
# https://www.immoweb.be/en/classified/loft/for-sale/kortrijk/8500/9518565
#  200
# 158603
# Written file ...9551501
# Written file ...9518565
# Made request
# https://www.immoweb.be/en/classified/duplex/for-sale/knokke-heist/8300/9559342
#  200
# 163078
# Written file ...9559342
# Made request
# https://www.immoweb.be/en/classified/apartment/for-sale/auderghem/1160/9557465
#  200
# 161766
# Written file ...9557465
# Made request
# https://www.immoweb.be/en/classified/house/for-sale/profondeville/5170/9534380
#  200
# 175546
# Written file ...9534380
# Made request
# https://www.immoweb.be/en/classified/apartment/for-sale/etterbeek/1040/9374417
#  200
# 161780
# Written file ...9374417
# Made request
# https://www.immoweb.be/en/classified/house/for-sale/waregem/8793/9255481
#  200
# 165613
# Written file ...9255481
# Made request
# https://www.immoweb.be/en/classified/duplex/for-sale/liege-1/4000/8549833
#  200
# 163860
# Written file ...8549833
# Made request
# https://www.immoweb.be/en/classified/house/for-sale/mouscron/7700/9469346
#  200
# 174183
# Written file ...9469346
# Made request
# https://www.immoweb.be/en/classified/house/for-sale/trooz/4870/9520291
#  200
# 178178
# Written file ...9520291
# Made request
# https://www.immoweb.be/en/classified/house/for-sale/evere/1140/9382725
#  200
# 174207
# Written file ...9382725
# Made request
# https://www.immoweb.be/en/classified/house/for-sale/antwerp/2000/9428428
#  200
# 174186
# Written file ...9428428
# All tasks completed.

# %% [markdown]
# Find the clickable for Search on the list and click on it

# %%
r = requests.get(urls[0])
# Display the requested url and the return of the server
print(urls[0], r.status_code)
# Store the HTML content of the website in a text
page_contents = r.content
# Out:
# https://www.immoweb.be/en/classified/apartment/for-sale/ixelles/1050/8956021
#  200

# %%
print(type(page_contents))
print(page_contents)
# Out:
# <class 'bytes'>
# b'<!doctype html>\n\n<html itemscope itemtype="http://schema.org/WebPage" lang="en">\n\n<head>\n    <meta charset="utf-8">\n\n    \n    \n    <script>\n    window.dataLayer = [\n        {\n            "user": {\n                "loginStatus": "logged out",\n                "id": "",\n                "personal": {\n                    "language": ""\n                }\n            },\n                                        "classified": {\n                "id": "8956021",\n                "type": "apartment",\n                "subtype": "apartment",\n                "price": "1150000",\n                "transactionType": "for sale",\n                "zip": "1050",\n                "visualisationOption": "xl",\n                "kitchen": {\n                    "type": "installed"\n                },\n                "building": {\n                    "constructionYear": "1930",\n                    "condition": "good"\n                },\n                "energy": {\n                    "heatingType": "fueloil"\n                },\n                "certificates": {\n                    "primaryEnergyConsumptionLevel": "142"\n                },\n                "bedroom": {\n                    "count": "3"\n                },\n                "land": {\n                    "surface": ""\n                },\n                "atticExists": "",\n                "basementExists": "true",\n                "outdoor": {\n                    "garden": {\n                        "surface": ""\n                    },\n                    "terrace": {\n                        "exists": ""\n                    }\n                },\n                "specificities": {\n                    "SME": {\n                        "office": {\n                            "exists": "true"\n                        }\n                    }\n                },\n                "wellnessEquipment": {\n                    "hasSwimmingPool": ""\n                },\n                "parking": {\n                    "parkingSpaceCount": {\n                        "indoor": "1",\n                        "outdoor": ""\n                    }\n                },\n                "condition": {\n                    "isNewlyBuilt": "false"\n                }\n            },\n                                    "customer": {\n                "id": "1453",\n                "name": "immobili\xc3\xa8re le lion",\n                "family" : "agency",\n                "groupInfo": {\n                    "id": "",\n                    "name": ""\n                },\n                "networkInfo": {\n                    "id" : "",\n                    "name": ""\n                }\n            },\n                                    "screen": {\n                "name": "classified details",\n                "language": "en"\n            }\n\n        }\n    ];\n</script>\n    <!-- Google Tag Manager -->\n<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\nnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=false;j.src=\n\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n})(window,document,\'script\',\'dataLayer\',\'GTM-M7L459B\');</script>\n<!-- End Google Tag Manager -->\n\n<!-- Special case : hardcode Kameleoon script -->\n<script type="text/javascript">window.kameleoonQueue = window.kameleoonQueue || [];</script>\n<script type="text/javascript" src="//8r26y3m3xw.kameleoon.eu/kameleoon.js"></script>\n<!-- End Kameleoon -->\n\n<!-- Google Optimize -->\n<!-- Anti-flicker snippet (recommended) -->\n<style>.async-hide\n    { opacity: 0 !important}\n\n</style>\n<script>\n    (function(a,s,y,n,c,h,i,d,e){s.className+=\' \'+y;h.start=1*new Date;\n        h.end=i=function()\n        {s.className=s.className.replace(RegExp(\' ?\'+y),\'\')}\n\n        ;\n        (a[n]=a[n]||[]).hide=h;setTimeout(function()\n            {i();h.end=null}\n\n   ...
